# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale 
from sklearn.linear_model import Ridge, Lasso, RidgeCV, LassoCV
from sklearn.metrics import mean_squared_error

from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.static import teams

# Gets the box score of every single game (NBA + WNBA + others: nba.com doesn't seperate the leagues) 
# from 2014-2021 into a dataframe.
all_games_finder = leaguegamefinder.LeagueGameFinder()
all_games = all_games_finder.get_data_frames()[0]

# Creates empty dataframe with the same column names passed in from the dataframe containing all the games.
column_names = all_games.columns
games = pd.DataFrame(columns = column_names)

# Appends every game containing an NBA team in the all_games df to the games df. 
nba_teams = teams.get_teams()
for team in nba_teams:
    temp_id = team['id']
    games = games.append(all_games[all_games['TEAM_ID'] == temp_id])

pd.set_option('display.max_columns', None)
games.head()
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION      TEAM_NAME     GAME_ID  \
# 6       22021  1610612737               ATL  Atlanta Hawks  0022100319
# 76      22021  1610612737               ATL  Atlanta Hawks  0022100293
# 121     22021  1610612737               ATL  Atlanta Hawks  0022100285
# 161     22021  1610612737               ATL  Atlanta Hawks  0022100277
# 200     22021  1610612737               ATL  Atlanta Hawks  0022100255
#
#       GAME_DATE      MATCHUP    WL  MIN  PTS FGM FGA  FG_PCT FG3M FG3A  \
# 6    2021-12-01    ATL @ IND  None  121   53  20  36   0.556    8   12
# 76   2021-11-27  ATL vs. NYK     L  240   90  33  93   0.355    9   37
# 121  2021-11-26    ATL @ MEM     W  239  132  52  89   0.584   13   27
# 161  2021-11-24    ATL @ SAS     W  239  124  45  88   0.511   12   26
# 200  2021-11-22  ATL vs. OKC     W  239  113  42  87   0.483   14   34
#
#      FG3_PCT FTM FTA  FT_PCT OREB DREB REB AST STL BLK TOV  PF  PLUS_MINUS
# 6      0.667   5   5   1.000    0   16  16   9   0   3   6   7         6.8
# 76     0.243  15  20   0.750   13   39  52  18   8   6   6  17        -9.0
# 121    0.481  15  21   0.714    9   40  49  33   8   5  12  15        32.0
# 161    0.462  22  24   0.917    8   36  44  26  10   5   9  11        18.0
# 200    0.412  15  16   0.938    8   36  44  25   6   6   7  16        12.0

# %%
# Dropping any game (two rows in DF) that has any NaN values or is missing either team's stats
games.isna()
games.dropna(inplace=True)

games = games[games.duplicated(subset = ['GAME_ID'], keep=False)]

# Merging games together (previously seperated in the DF by team: each team's stats from the game were kept in seperate rows
games = games.sort_values(by=['GAME_ID'])
games = games.reset_index(drop=True)

# Team A and B each have a row for their stats in a given matchup; we need to add both stats to the end of their respective rows
# Team A dataframe
tempA = games[games.index % 2 == 0]
tempA2 = games[games.index % 2 == 1]

tempA2 = tempA2.add_prefix('OPP_')

tempA = tempA.reset_index(drop=True)
tempA2 = tempA2.reset_index(drop=True)

a_temp = tempA.join(tempA2)

# Team B dataframe
tempB = games[games.index % 2 == 0]
tempB2 = games[games.index % 2 == 1]

tempB = tempB.add_prefix('OPP_')

tempB = tempB.reset_index(drop=True)
tempB2 = tempB2.reset_index(drop=True)

b_temp = tempB2.join(tempB)

# Adding both teams to main dataframe
games = a_temp.append(b_temp)

# Resorting main dataframe
games = games.sort_values(by=['GAME_ID'])
games = games.reset_index(drop=True)

# Sending data to CSV
games.to_csv('games.csv', index = False)

# Print Head
pd.set_option('display.max_columns', None)
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION          TEAM_NAME     GAME_ID  \
# 0     12015  1610612743               DEN     Denver Nuggets  0011500001
# 1     12015  1610612746               LAC        LA Clippers  0011500001
# 2     12015  1610612753               ORL      Orlando Magic  0011500002
# 3     12015  1610612766               CHA  Charlotte Hornets  0011500002
# 4     12015  1610612754               IND     Indiana Pacers  0011500003
#
#     GAME_DATE      MATCHUP WL  MIN  PTS FGM FGA  FG_PCT FG3M FG3A  FG3_PCT  \
# 0  2015-10-02    DEN @ LAC  L  240   96  37  87   0.425    7   18    0.389
# 1  2015-10-02  LAC vs. DEN  W  238  103  37  91   0.407    9   32    0.281
# 2  2015-10-03  ORL vs. CHA  L  240  100  39  89   0.438    6   26    0.231
# 3  2015-10-03    CHA @ ORL  W  241  106  34  75   0.453   12   31    0.387
# 4  2015-10-03  IND vs. NOP  L  241  105  38  92   0.413   10   35    0.286
#
#   FTM FTA  FT_PCT OREB DREB REB AST STL BLK TOV  PF  PLUS_MINUS OPP_SEASON_ID  \
# 0  15  20   0.750   14   43  57  16   9   2  23  26        -7.0         12015
# 1  20  26   0.769    9   30  39  22  12   6  13  15         7.0         12015
# 2  16  19   0.842   12   33  45  22  11   3  12  30        -6.0         12015
# 3  26  35   0.743    7   34  41  30   7   2  13  15         6.0         12015
# 4  19  31   0.613   18   44  62  21  10  16  19  27        -5.0         12015
#
#   OPP_TEAM_ID OPP_TEAM_ABBREVIATION         OPP_TEAM_NAME OPP_GAME_ID  \
# 0  1610612746                   LAC           LA Clippers  0011500001
# 1  1610612743                   DEN        Denver Nuggets  0011500001
# 2  1610612766                   CHA     Charlotte Hornets  0011500002
# 3  1610612753                   ORL         Orlando Magic  0011500002
# 4  1610612740                   NOP  New Orleans Pelicans  0011500003
#
#   OPP_GAME_DATE  OPP_MATCHUP OPP_WL OPP_MIN OPP_PTS OPP_FGM OPP_FGA  \
# 0    2015-10-02  LAC vs. DEN      W     238     103      37      91
# 1    2015-10-02    DEN @ LAC      L     240      96      37      87
# 2    2015-10-03    CHA @ ORL      W     241     106      34      75
# 3    2015-10-03  ORL vs. CHA      L     240     100      39      89
# 4    2015-10-03    NOP @ IND      W     242     110      37     103
#
#    OPP_FG_PCT OPP_FG3M OPP_FG3A  OPP_FG3_PCT OPP_FTM OPP_FTA  OPP_FT_PCT  \
# 0       0.407        9       32        0.281      20      26       0.769
# 1       0.425        7       18        0.389      15      20       0.750
# 2       0.453       12       31        0.387      26      35       0.743
# 3       0.438        6       26        0.231      16      19       0.842
# 4       0.359       11       32        0.344      25      37       0.676
#
#   OPP_OREB OPP_DREB OPP_REB OPP_AST OPP_STL OPP_BLK OPP_TOV OPP_PF  \
# 0        9       30      39      22      12       6      13     15
# 1       14       43      57      16       9       2      23     26
# 2        7       34      41      30       7       2      13     15
# 3       12       33      45      22      11       3      12     30
# 4       19       36      55      16       9       3      11     22
#
#    OPP_PLUS_MINUS
# 0             7.0
# 1            -7.0
# 2             6.0
# 3            -6.0
# 4             5.0

# %%
temp_games = pd.DataFrame()
nba_teams = teams.get_teams()
for team in nba_teams:
    temp_id = team['id']
    temp_games = temp_games.append(games[games['TEAM_ID'] == temp_id])

games = temp_games

# Print Head
pd.set_option('display.max_columns', None)
games.head()
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION      TEAM_NAME     GAME_ID  \
# 29      12015  1610612737               ATL  Atlanta Hawks  0011500017
# 52      12015  1610612737               ATL  Atlanta Hawks  0011500032
# 102     12015  1610612737               ATL  Atlanta Hawks  0011500060
# 119     12015  1610612737               ATL  Atlanta Hawks  0011500068
# 143     12015  1610612737               ATL  Atlanta Hawks  0011500081
#
#       GAME_DATE      MATCHUP WL  MIN  PTS FGM FGA  FG_PCT FG3M FG3A  FG3_PCT  \
# 29   2015-10-07    ATL @ CLE  W  238   98  33  75   0.440    7   24    0.292
# 52   2015-10-09    ATL @ NOP  W  240  103  33  74   0.446   11   26    0.423
# 102  2015-10-14  ATL vs. SAS  W  240  100  32  78   0.410   11   31    0.355
# 119  2015-10-16    ATL @ DAL  W  241   91  31  84   0.369    9   28    0.321
# 143  2015-10-18  ATL vs. MIA  L  240   92  33  75   0.440    6   22    0.273
#
#     FTM FTA  FT_PCT OREB DREB REB AST STL BLK TOV  PF  PLUS_MINUS  \
# 29   25  30   0.833    9   37  46  17   8   2  17  19         2.0
# 52   26  36   0.722    5   43  48  21   8   5  16  23        10.0
# 102  25  29   0.862    3   45  48  24  10   4  16  26        14.0
# 119  20  24   0.833    9   40  49  18   9   7  15  14         7.0
# 143  20  22   0.909    8   36  44  23   6   9  22  24        -9.0
#
#     OPP_SEASON_ID OPP_TEAM_ID OPP_TEAM_ABBREVIATION         OPP_TEAM_NAME  \
# 29          12015  1610612739                   CLE   Cleveland Cavaliers
# 52          12015  1610612740                   NOP  New Orleans Pelicans
# 102         12015  1610612759                   SAS     San Antonio Spurs
# 119         12015  1610612742                   DAL      Dallas Mavericks
# 143         12015  1610612748                   MIA            Miami Heat
#
#     OPP_GAME_ID OPP_GAME_DATE  OPP_MATCHUP OPP_WL OPP_MIN OPP_PTS OPP_FGM  \
# 29   0011500017    2015-10-07  CLE vs. ATL      L     239      96      35
# 52   0011500032    2015-10-09  NOP vs. ATL      L     238      93      32
# 102  0011500060    2015-10-14    SAS @ ATL      L     240      86      27
# 119  0011500068    2015-10-16  DAL vs. ATL      L     241      84      31
# 143  0011500081    2015-10-18    MIA @ ATL      W     240     101      36
#
#     OPP_FGA  OPP_FG_PCT OPP_FG3M OPP_FG3A  OPP_FG3_PCT OPP_FTM OPP_FTA  \
# 29       83       0.422       14       37        0.378      12      15
# 52       84       0.381        7       27        0.259      22      31
# 102      82       0.329        4       20        0.200      28      36
# 119      85       0.365        9       33        0.273      13      17
# 143      92       0.391       10       30        0.333      19      25
#
#      OPP_FT_PCT OPP_OREB OPP_DREB OPP_REB OPP_AST OPP_STL OPP_BLK OPP_TOV  \
# 29        0.800        7       32      39      28      10       7      17
# 52        0.710        6       38      44      15       8       7      13
# 102       0.778       11       39      50      17       9       2      18
# 119       0.765        8       41      49      18       8       6      18
# 143       0.760       15       29      44      26       8       2      13
#
#     OPP_PF  OPP_PLUS_MINUS
# 29      29            -2.0
# 52      26           -10.0
# 102     25           -14.0
# 119     19            -7.0
# 143     16             9.0

# %%
# Storing some columns for future use
game_ids = games['GAME_ID'].values
team_ids = games['TEAM_ID'].values
minutes = games['MIN'].values
abrv = games['TEAM_ABBREVIATION'].values
spread = games['PLUS_MINUS'].values

# Dropping Non-essential categorical data
games = games.drop(columns=['SEASON_ID', 'OPP_SEASON_ID', 'OPP_TEAM_ID','GAME_ID', 'OPP_GAME_ID', 'TEAM_ABBREVIATION', 'OPP_TEAM_ABBREVIATION', 'TEAM_NAME', 'OPP_TEAM_NAME', 'MATCHUP', 'OPP_MATCHUP', 'WL', 'OPP_WL', 'GAME_DATE', 'OPP_GAME_DATE', 'MIN', 'OPP_MIN']) 

# Adding minutes back as a single column
games['MIN'] = minutes

# Print Head
pd.set_option('display.max_columns', None)
games.head()
# Out:
#         TEAM_ID  PTS FGM FGA  FG_PCT FG3M FG3A  FG3_PCT FTM FTA  FT_PCT OREB  \
# 29   1610612737   98  33  75   0.440    7   24    0.292  25  30   0.833    9
# 52   1610612737  103  33  74   0.446   11   26    0.423  26  36   0.722    5
# 102  1610612737  100  32  78   0.410   11   31    0.355  25  29   0.862    3
# 119  1610612737   91  31  84   0.369    9   28    0.321  20  24   0.833    9
# 143  1610612737   92  33  75   0.440    6   22    0.273  20  22   0.909    8
#
#     DREB REB AST STL BLK TOV  PF  PLUS_MINUS OPP_PTS OPP_FGM OPP_FGA  \
# 29    37  46  17   8   2  17  19         2.0      96      35      83
# 52    43  48  21   8   5  16  23        10.0      93      32      84
# 102   45  48  24  10   4  16  26        14.0      86      27      82
# 119   40  49  18   9   7  15  14         7.0      84      31      85
# 143   36  44  23   6   9  22  24        -9.0     101      36      92
#
#      OPP_FG_PCT OPP_FG3M OPP_FG3A  OPP_FG3_PCT OPP_FTM OPP_FTA  OPP_FT_PCT  \
# 29        0.422       14       37        0.378      12      15       0.800
# 52        0.381        7       27        0.259      22      31       0.710
# 102       0.329        4       20        0.200      28      36       0.778
# 119       0.365        9       33        0.273      13      17       0.765
# 143       0.391       10       30        0.333      19      25       0.760
#
#     OPP_OREB OPP_DREB OPP_REB OPP_AST OPP_STL OPP_BLK OPP_TOV OPP_PF  \
# 29         7       32      39      28      10       7      17     29
# 52         6       38      44      15       8       7      13     26
# 102       11       39      50      17       9       2      18     25
# 119        8       41      49      18       8       6      18     19
# 143       15       29      44      26       8       2      13     16
#
#      OPP_PLUS_MINUS  MIN
# 29             -2.0  238
# 52            -10.0  240
# 102           -14.0  240
# 119            -7.0  241
# 143             9.0  240

# %%
# Adding Advanced Stats to enhance model performance, formulas were gathered from various sources. 

# Efficient Field Goal Percentage
games['EFG%'] = (games['FGM'] + (.5 * games['FG3M'])) / games['FGA']
games['OPP_EFG%'] = (games['OPP_FGM'] + (.5 * games['OPP_FG3M'])) / games['OPP_FGA']

# Block Percentage
games['BLK%'] = (games['BLK'] / (games['OPP_FGA']-games['OPP_FG3A']))
games['OPP_BLK%'] = (games['OPP_BLK'] / (games['FGA']-games['FG3A']))

# Turnover Percentage
games['TOV%'] = games['TOV'] / (games['FGA'] + 0.44 * games['FTA'] + games['TOV'])
games['OPP_TOV%'] = games['OPP_TOV'] / (games['OPP_FGA'] + 0.44 * games['OPP_FTA'] + games['OPP_TOV'])

#Offensive Rebound Percentage
games['ORB%'] = games['OREB'] / (games['OREB'] + games['OPP_DREB'])
games['OPP_ORB%'] = games['OPP_OREB'] / (games['OPP_OREB'] + games['DREB'])

#Defensive Rebound Percentage
games['DREB%'] = games['DREB'] / (games['OPP_OREB'] + games['DREB'])
games['OPP_DREB%'] = games['OPP_DREB'] / (games['OREB'] + games['OPP_DREB'])

# Possessions
#games["POSS"] = 0.5*((games["FGA"] + 0.4*games["FTA"] - 1.07*(games["OREB"]/(games["OREB"] + games["OREB_other"])) * (games["FGA"] - games["FGM"]) + games["TOV"]) + games["FGA_other"] + 0.4*games["FTA_other"] - 1.07 * (games["OREB_other"] / (games["OREB_other"] + games["DREB"])) * (games["FGA_other"] - games["FGM_other]) + games["TOV_other"]))

# ***Placeholder POSS***
games['POSS'] = 0.96*((games['FGA']) + games['TOV'] + 0.44 * games['FTA'] - games['OREB'])
games['OPP_POSS'] = 0.96*((games['OPP_FGA']) + games['OPP_TOV'] + 0.44 * games['OPP_FTA'] - games['OPP_OREB'])

# Steals Percentage
games['STL%'] = (games['STL'] / games['OPP_POSS'])
games['OPP_STL%'] = (games['OPP_STL'] / games['POSS'])

# Free Throw Rate
games['FTR'] = games['FTM'] / games['FGA']
games['OPP_FTR'] = games['OPP_FTM'] / games['OPP_FGA']

# True Shooting (Requires True Shooting Attempts)
tsa = games['FGA'] + 0.44 * games['FTA']
OPP_tsa = games['OPP_FGA'] + 0.44 * games['OPP_FTA']
games['TS'] = games['PTS'] / (2 * tsa)
games['OPP_TS'] = games['OPP_PTS'] / (2 * OPP_tsa)

# Assist Rate
games['ASTR'] = games['AST'] / (games['FGA'] + (.44 * games['FTA']) + games['AST'] + games['TOV'])
games['OPP_ASTR'] = games['OPP_AST'] / (games['OPP_FGA'] + (.44 * games['OPP_FTA']) + games['OPP_AST'] + games['OPP_TOV'])

# Total Rebound Percentage
games['TRB%'] = (games['REB'] * (games['REB'] / 5)) / (games['MIN'] * (games['REB'] + games['OPP_REB']))
games['OPP_TRB%'] = (games['OPP_REB'] * (games['OPP_REB'] / 5)) / (games['MIN'] * (games['OPP_REB'] + games['REB']))

# PACE
games['PACE'] = 48 * (games['POSS'] + games['OPP_POSS']) / (2 * (games['MIN'] / 5))
games['OPP_PACE'] = 48 * (games['OPP_POSS'] + games['POSS']) / (2 * (games['MIN'] / 5))

# Offensive Rating
games['ORTG'] = (games['PTS'] / games['POSS'])
games['OPP_ORTG'] = (games['OPP_PTS'] / games['OPP_POSS'])

# Defensive Rating
games['DRTG'] = (games['OPP_PTS'] / games['POSS'])
games['OPP_DRTG'] = (games['PTS'] / games['OPP_POSS'])

games.head()
# Out:
#         TEAM_ID  PTS FGM FGA  FG_PCT FG3M FG3A  FG3_PCT FTM FTA  FT_PCT OREB  \
# 29   1610612737   98  33  75   0.440    7   24    0.292  25  30   0.833    9
# 52   1610612737  103  33  74   0.446   11   26    0.423  26  36   0.722    5
# 102  1610612737  100  32  78   0.410   11   31    0.355  25  29   0.862    3
# 119  1610612737   91  31  84   0.369    9   28    0.321  20  24   0.833    9
# 143  1610612737   92  33  75   0.440    6   22    0.273  20  22   0.909    8
#
#     DREB REB AST STL BLK TOV  PF  PLUS_MINUS OPP_PTS OPP_FGM OPP_FGA  \
# 29    37  46  17   8   2  17  19         2.0      96      35      83
# 52    43  48  21   8   5  16  23        10.0      93      32      84
# 102   45  48  24  10   4  16  26        14.0      86      27      82
# 119   40  49  18   9   7  15  14         7.0      84      31      85
# 143   36  44  23   6   9  22  24        -9.0     101      36      92
#
#      OPP_FG_PCT OPP_FG3M OPP_FG3A  OPP_FG3_PCT OPP_FTM OPP_FTA  OPP_FT_PCT  \
# 29        0.422       14       37        0.378      12      15       0.800
# 52        0.381        7       27        0.259      22      31       0.710
# 102       0.329        4       20        0.200      28      36       0.778
# 119       0.365        9       33        0.273      13      17       0.765
# 143       0.391       10       30        0.333      19      25       0.760
#
#     OPP_OREB OPP_DREB OPP_REB OPP_AST OPP_STL OPP_BLK OPP_TOV OPP_PF  \
# 29         7       32      39      28      10       7      17     29
# 52         6       38      44      15       8       7      13     26
# 102       11       39      50      17       9       2      18     25
# 119        8       41      49      18       8       6      18     19
# 143       15       29      44      26       8       2      13     16
#
#      OPP_PLUS_MINUS  MIN      EFG%  OPP_EFG%      BLK%  OPP_BLK%      TOV%  \
# 29             -2.0  238  0.486667  0.506024  0.043478  0.137255  0.161597
# 52            -10.0  240   0.52027  0.422619  0.087719  0.145833  0.151172
# 102           -14.0  240  0.480769  0.353659  0.064516  0.042553  0.149869
# 119            -7.0  241  0.422619  0.417647  0.134615  0.107143  0.136911
# 143             9.0  240      0.48  0.445652  0.145161  0.037736  0.206224
#
#      OPP_TOV%      ORB%  OPP_ORB%     DREB% OPP_DREB%     POSS  OPP_POSS  \
# 29   0.159475  0.219512  0.159091  0.840909  0.780488   92.352    95.616
# 52   0.117498  0.116279  0.122449  0.877551  0.883721  96.8064  100.4544
# 102  0.155387  0.071429  0.196429  0.803571  0.928571  99.6096  100.6464
# 119  0.162925      0.18  0.166667  0.833333      0.82  96.5376   98.3808
# 143  0.112069  0.216216  0.294118  0.705882  0.783784  94.7328     96.96
#
#          STL%  OPP_STL%       FTR   OPP_FTR        TS    OPP_TS      ASTR  \
# 29   0.083668  0.108281  0.333333  0.144578  0.555556  0.535714  0.139116
# 52   0.079638  0.082639  0.351351  0.261905  0.573241  0.476239  0.165563
# 102  0.099358  0.090353  0.320513  0.341463  0.550903  0.439493  0.183542
# 119  0.091481  0.082869  0.238095  0.152941  0.481176  0.454152   0.14111
# 143  0.061881  0.084448  0.266667  0.206522  0.543222  0.490291   0.17736
#
#      OPP_ASTR      TRB%  OPP_TRB%       PACE   OPP_PACE      ORTG  OPP_ORTG  \
# 29   0.208024  0.020919  0.015037  94.773782  94.773782  1.061157  1.004016
# 52   0.119389   0.02087  0.017536    98.6304    98.6304  1.063979  0.925793
# 102  0.127974  0.019592  0.021259    100.128    100.128  1.003919  0.854477
# 119    0.1401  0.020332  0.020332  97.054805  97.054805  0.942638  0.853825
# 143  0.183099  0.018333  0.018333    95.8464    95.8464  0.971153  1.041667
#
#          DRTG  OPP_DRTG
# 29   1.039501  1.024933
# 52    0.96068  1.025341
# 102  0.863371  0.993578
# 119  0.870127  0.924977
# 143  1.066157  0.948845

# %%
# Test/Train splitting
#y = games["PLUS_MINUS"].values
#games.drop(columns=['PLUS_MINUS', 'OPP_PLUS_MINUS'], inplace=True)
#x = games.values
print(x.shape)
print(y.shape)
xtrain, xtest, ytrain, ytest =  train_test_split(x,y, test_size = 0.2, random_state=1)
# Out:
# (17890, 66)
# (17890,)

# %%
# Attempting to make a model, finally
ridge = Ridge(alpha=1.0)
ridge.fit(xtrain, ytrain)

predict = ridge.predict(xtest)

print(pd.Series(ridge.coef_, index = games.columns[0:66])) 
mse = mean_squared_error(ytest, predict) 
print("Test mean squared error (MSE): {:.2f}".format(mse))
print(ridge.score(xtest,ytest))
# Out:
# TEAM_ID     0.001006
# PTS         0.896785
# FGM         0.303160
# FGA        -0.011722
# FG_PCT     -0.673225
#               ...
# OPP_PACE    0.001359
# ORTG       -1.428887
# OPP_ORTG    1.743555
# DRTG        2.742789
# OPP_DRTG   -2.344719
# Length: 66, dtype: float64
# Test mean squared error (MSE): 0.59
# 0.9971176787606796

# %%
#Adding Rolling averages to emulate how a team settles/grows in ability during a season/seasons
#games_averages = pd.concat([games.rolling(5).mean() for _, d in games.groupby('TEAM_ID')])
games_averages = games.copy()
games_averages = games_averages.groupby('TEAM_ID')
games_averages = games_averages.rolling(5).mean()
games_averages = games_averages.reset_index(drop=True)

# Converting entire DF to numeric
games_averages = games_averages.apply(pd.to_numeric, errors='coerce')

# Print Head
pd.set_option('display.float_format', '{:.2f}'.format)
pd.set_option('display.max_columns', None)
games_averages.head(30)
# Out:
#          TEAM_ID    PTS   FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT   FTM   FTA  \
# 0            NaN    NaN   NaN   NaN     NaN   NaN   NaN      NaN   NaN   NaN
# 1            NaN    NaN   NaN   NaN     NaN   NaN   NaN      NaN   NaN   NaN
# 2            NaN    NaN   NaN   NaN     NaN   NaN   NaN      NaN   NaN   NaN
# 3            NaN    NaN   NaN   NaN     NaN   NaN   NaN      NaN   NaN   NaN
# 4  1610612737.00  96.80 32.40 77.20    0.42  8.80 26.20     0.33 23.20 28.20
# 5  1610612737.00  93.40 32.00 78.60    0.41  9.00 26.60     0.34 20.40 25.60
# 6  1610612737.00  90.20 32.00 79.80    0.40  8.20 25.20     0.33 18.00 21.80
# 7  1610612737.00  91.00 33.80 81.40    0.42  7.40 23.20     0.32 16.00 20.60
# 8  1610612737.00  91.00 34.40 81.00    0.42  6.80 21.20     0.32 15.40 19.20
# 9  1610612737.00  92.40 35.40 82.60    0.43  6.00 20.60     0.29 15.60 21.00
# 10 1610612737.00  95.00 36.40 82.80    0.44  6.60 21.00     0.31 15.60 20.80
# 11 1610612737.00  98.60 37.00 84.40    0.44  7.20 22.60     0.31 17.40 22.80
# 12 1610612737.00  97.00 36.00 84.40    0.43  7.00 22.60     0.30 18.00 23.40
# 13 1610612737.00  98.20 37.20 85.00    0.44  7.40 24.00     0.29 16.40 22.60
# 14 1610612737.00  96.40 35.80 85.80    0.42  8.20 25.20     0.32 16.60 21.80
# 15 1610612737.00  99.40 36.40 85.40    0.43  8.40 27.20     0.31 18.20 23.80
# 16 1610612737.00  95.80 35.40 84.80    0.42  9.20 29.00     0.31 15.80 21.40
# 17 1610612737.00  96.60 35.20 83.00    0.43 10.00 30.80     0.32 16.20 21.20
# 18 1610612737.00  96.00 33.40 82.00    0.41 10.20 31.20     0.32 19.00 25.00
# 19 1610612737.00 101.20 36.80 85.60    0.43 10.60 32.80     0.32 17.00 23.20
# 20 1610612737.00 101.40 36.40 86.20    0.42 11.40 33.80     0.33 17.20 24.40
# 21 1610612737.00 102.80 36.20 85.00    0.42 11.00 34.40     0.32 19.40 27.80
# 22 1610612737.00 108.80 39.00 86.40    0.45 11.80 35.20     0.33 19.00 27.80
# 23 1610612737.00 112.60 41.20 89.00    0.46 12.60 37.80     0.33 17.60 24.80
# 24 1610612737.00 111.20 39.60 85.40    0.46 13.80 39.40     0.35 18.20 26.00
# 17     97.57  0.07      0.08 0.20     0.16 0.52    0.49  0.18      0.18  0.02
# 18     96.20  0.08      0.08 0.23     0.14 0.52    0.54  0.17      0.19  0.02
# 19     99.46  0.07      0.08 0.21     0.13 0.53    0.52  0.18      0.18  0.02
# 20    101.11  0.08      0.08 0.21     0.18 0.52    0.54  0.17      0.17  0.02
# 21    104.95  0.09      0.10 0.24     0.23 0.53    0.53  0.16      0.16  0.02
# 22    104.29  0.09      0.08 0.23     0.23 0.55    0.56  0.17      0.17  0.02
# 23    107.95  0.09      0.08 0.20     0.28 0.57    0.56  0.17      0.16  0.02
# 24    107.95  0.09      0.10 0.22     0.30 0.57    0.59  0.16      0.16  0.02
# 25    106.51  0.08      0.11 0.22     0.27 0.56    0.56  0.16      0.16  0.02
# 26    105.75  0.08      0.10 0.21     0.26 0.56    0.58  0.16      0.17  0.02
# 27    106.21  0.08      0.10 0.20     0.27 0.51    0.55  0.16      0.16  0.02
# 28    103.77  0.07      0.10 0.21     0.24 0.50    0.54  0.16      0.16  0.02
# 29    102.04  0.08      0.09 0.24     0.24 0.49    0.53  0.15      0.17  0.02
#
#     OPP_TRB%   PACE  OPP_PACE  ORTG  OPP_ORTG  DRTG  OPP_DRTG
# 0        NaN    NaN       NaN   NaN       NaN   NaN       NaN
# 1        NaN    NaN       NaN   NaN       NaN   NaN       NaN
# 2        NaN    NaN       NaN   NaN       NaN   NaN       NaN
# 3        NaN    NaN       NaN   NaN       NaN   NaN       NaN
# 4       0.02  97.29     97.29  1.01      0.94  0.96      0.98
# 5       0.02  97.07     97.07  0.97      0.91  0.93      0.95
# 6       0.02  95.78     95.78  0.94      0.98  0.98      0.94
# 7       0.02  94.44     94.44  0.96      0.99  0.98      0.96
# 8       0.02  93.94     93.94  0.97      1.03  1.03      0.97
# 9       0.02  94.55     94.55  0.97      1.01  1.00      0.98
# 10      0.02  95.00     95.00  0.99      1.04  1.03      1.00
# 11      0.02  95.51     95.51  1.03      0.99  0.99      1.03
# 12      0.02  96.61     96.61  1.01      0.99  1.00      1.00
# 13      0.02  97.26     97.26  1.01      0.94  0.95      1.01
# 14      0.02  97.24     97.24  1.00      0.95  0.96      0.99
# 15      0.02  98.17     98.17  1.01      0.93  0.93      1.01
# 16      0.02  97.80     97.80  0.97      0.96  0.95      0.98
# 17      0.02  98.24     98.24  0.97      0.96  0.94      0.99
# 18      0.02  97.69     97.69  0.96      1.03  0.99      1.00
# 19      0.02 100.84    100.84  0.99      1.02  0.98      1.02
# 20      0.02 102.46    102.46  0.98      1.05  1.02      1.00
# 21      0.02 105.21    105.21  0.97      1.02  1.01      0.98
# 22      0.02 104.38    104.38  1.05      1.10  1.10      1.05
# 23      0.02 107.30    107.30  1.06      1.08  1.10      1.05
# 24      0.02 106.98    106.98  1.05      1.14  1.16      1.04
# 25      0.02 105.72    105.72  1.02      1.11  1.12      1.01
# 26      0.02 105.43    105.43  1.01      1.13  1.13      1.00
# 27      0.02 105.84    105.84  0.94      1.06  1.06      0.94
# 28      0.02 103.32    103.32  0.92      1.07  1.08      0.92
# 29      0.02 102.30    102.30  0.94      1.06  1.05      0.94

# %%
# games DF will now have the average stats of a teams most recent 10 games
#games = games_averages

# # Normalize Data
# realcols = list(games.columns.values)

# for col in realcols:
#   mean = games[col].mean()
#   std = games[col].std()
#   games[col] = (games[col] - mean)/std

# Sending data to CSV
games.to_csv('games.csv', index = False)
games_averages.to_csv('games_averages.csv', index = False)d

# Print head
pd.set_option('display.max_columns', None)
games.head()
# Out:
#         TEAM_ID   PTS   FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT   FTM   FTA  \
# 0           NaN   NaN   NaN   NaN     NaN   NaN   NaN      NaN   NaN   NaN
# 1           NaN   NaN   NaN   NaN     NaN   NaN   NaN      NaN   NaN   NaN
# 2           NaN   NaN   NaN   NaN     NaN   NaN   NaN      NaN   NaN   NaN
# 3           NaN   NaN   NaN   NaN     NaN   NaN   NaN      NaN   NaN   NaN
# 4 1610612737.00 96.80 32.40 77.20    0.42  8.80 26.20     0.33 23.20 28.20
#
#    FT_PCT  OREB  DREB   REB   AST  STL  BLK   TOV    PF  PLUS_MINUS  OPP_PTS  \
# 0     NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN   NaN         NaN      NaN
# 1     NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN   NaN         NaN      NaN
# 2     NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN   NaN         NaN      NaN
# 3     NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN   NaN         NaN      NaN
# 4    0.83  6.80 40.20 47.00 20.60 8.20 5.40 17.20 21.20        4.80    92.00
#
#    OPP_FGM  OPP_FGA  OPP_FG_PCT  OPP_FG3M  OPP_FG3A  OPP_FG3_PCT  OPP_FTM  \
# 0      NaN      NaN         NaN       NaN       NaN          NaN      NaN
# 1      NaN      NaN         NaN       NaN       NaN          NaN      NaN
# 2      NaN      NaN         NaN       NaN       NaN          NaN      NaN
# 3      NaN      NaN         NaN       NaN       NaN          NaN      NaN
# 4    32.20    85.20        0.38      8.80     29.40         0.29    18.80
#
#    OPP_FTA  OPP_FT_PCT  OPP_OREB  OPP_DREB  OPP_REB  OPP_AST  OPP_STL  \
# 0      NaN         NaN       NaN       NaN      NaN      NaN      NaN
# 1      NaN         NaN       NaN       NaN      NaN      NaN      NaN
# 2      NaN         NaN       NaN       NaN      NaN      NaN      NaN
# 3      NaN         NaN       NaN       NaN      NaN      NaN      NaN
# 4    24.80        0.76      9.40     35.80    45.20    20.80     8.60
#
#    OPP_BLK  OPP_TOV  OPP_PF  OPP_PLUS_MINUS    MIN  EFG%  OPP_EFG%  BLK%  \
# 0      NaN      NaN     NaN             NaN    NaN   NaN       NaN   NaN
# 1      NaN      NaN     NaN             NaN    NaN   NaN       NaN   NaN
# 2      NaN      NaN     NaN             NaN    NaN   NaN       NaN   NaN
# 3      NaN      NaN     NaN             NaN    NaN   NaN       NaN   NaN
# 4     4.80    15.80   23.00           -4.80 239.80  0.48      0.43  0.10
#
#    OPP_BLK%  TOV%  OPP_TOV%  ORB%  OPP_ORB%  DREB%  OPP_DREB%  POSS  OPP_POSS  \
# 0       NaN   NaN       NaN   NaN       NaN    NaN        NaN   NaN       NaN
# 1       NaN   NaN       NaN   NaN       NaN    NaN        NaN   NaN       NaN
# 2       NaN   NaN       NaN   NaN       NaN    NaN        NaN   NaN       NaN
# 3       NaN   NaN       NaN   NaN       NaN    NaN        NaN   NaN       NaN
# 4      0.09  0.16      0.14  0.16      0.19   0.81       0.84 96.01     98.41
#
#    STL%  OPP_STL%  FTR  OPP_FTR   TS  OPP_TS  ASTR  OPP_ASTR  TRB%  OPP_TRB%  \
# 0   NaN       NaN  NaN      NaN  NaN     NaN   NaN       NaN   NaN       NaN
# 1   NaN       NaN  NaN      NaN  NaN     NaN   NaN       NaN   NaN       NaN
# 2   NaN       NaN  NaN      NaN  NaN     NaN   NaN       NaN   NaN       NaN
# 3   NaN       NaN  NaN      NaN  NaN     NaN   NaN       NaN   NaN       NaN
# 4  0.08      0.09 0.30     0.22 0.54    0.48  0.16      0.16  0.02      0.02
#
#    PACE  OPP_PACE  ORTG  OPP_ORTG  DRTG  OPP_DRTG
# 0   NaN       NaN   NaN       NaN   NaN       NaN
# 1   NaN       NaN   NaN       NaN   NaN       NaN
# 2   NaN       NaN   NaN       NaN   NaN       NaN
# 3   NaN       NaN   NaN       NaN   NaN       NaN
# 4 97.29     97.29  1.01      0.94  0.96      0.98
